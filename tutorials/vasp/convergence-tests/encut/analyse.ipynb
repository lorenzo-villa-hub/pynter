# %%
from pynter.data.datasets import Dataset

ds = Dataset.from_directory('.')

# %%
ds
# Out:
#                        formula      group nodes  is_converged
# job_name
# AN_pure_cutoff300  Nb8 Ag8 O24  cutoff300                True
# AN_pure_cutoff400  Nb8 Ag8 O24  cutoff400                True
# AN_pure_cutoff500  Nb8 Ag8 O24  cutoff500                True
# AN_pure_cutoff600  Nb8 Ag8 O24  cutoff600                True
# AN_pure_cutoff700  Nb8 Ag8 O24  cutoff700                True

# %%
from pynter.vasp.analysis import DatasetAnalysis

da = DatasetAnalysis(ds.jobs)

# %%
da.plot_convergence_encut()
# Out:
# <module 'matplotlib.pyplot' from '/nfshome/villa/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>
